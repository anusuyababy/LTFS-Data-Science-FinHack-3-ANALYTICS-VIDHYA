# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
test=pd.read_excel('test_data.xlsx')
test.head()
# Out:
#     ID    Frequency InstlmentMode LoanStatus PaymentMode  BranchID     Area  \
# 0    4      Monthly       Advance     Closed       PDC_E         2     GUNA
# 1    5      Monthly       Advance     Closed         PDC         2     GUNA
# 2    6      Quatrly        Arrear     Closed         PDC         2     GUNA
# 3   25  Half Yearly        Arrear     Closed      Billed       154      NaN
# 4  119      Quatrly        Arrear     Closed         PDC       194  CUTTACK
#
#    Tenure  AssetCost  AmountFinance  DisbursalAmount      EMI DisbursalDate  \
# 0      46     480000       365000.0         365000.0   1000.0    2011-12-29
# 1      45     480000       285000.0         285000.0   9300.0    2012-04-28
# 2      48     580000       400000.0         400000.0  35800.0    2013-10-22
# 3      36     725000       500000.0         500000.0  52000.0    2013-05-21
# 4      48     617000       400000.0         400000.0  35400.0    2012-11-30
#
# ...

# %%
test.shape
# Out:
# (14745, 25)

# %%
test.isnull().sum()
# Out:
# ID                   0
# Frequency            0
# InstlmentMode        0
# LoanStatus           0
# PaymentMode          0
# BranchID             0
# Area               546
# Tenure               0
# AssetCost            0
# AmountFinance        0
# DisbursalAmount      0
# EMI                  0
# DisbursalDate        0
# MaturityDAte         0
# AuthDate             0
# AssetID              0
# ManufacturerID       2
# SupplierID           0
# LTV                  0
# SEX                  5
# AGE                  7
# MonthlyIncome       14
# City                 0
# State                0
# ZiPCODE              1
# dtype: int64

# %%
test_b=pd.read_excel('test_bureau.xlsx')
test_b.head()
# Out:
#    ID  SELF-INDICATOR MATCH-TYPE      ACCT-TYPE CONTRIBUTOR-TYPE  \
# 0   4           False    PRIMARY    Credit Card              CCC
# 1   4           False    PRIMARY   Housing Loan              HFC
# 2   4           False    PRIMARY  Property Loan              HFC
# 3   4            True    PRIMARY   Tractor Loan              NBF
# 4   5           False    PRIMARY      Gold Loan              PRB
#
#   DATE-REPORTED OWNERSHIP-IND ACCOUNT-STATUS DISBURSED-DT  \
# 0    2019-11-17    Individual         Active   2019-09-26
# 1    2019-10-31         Joint         Active   2017-06-21
# 2    2019-10-31         Joint         Active   2017-06-27
# 3    2015-10-31    Individual         Closed   2011-12-29
# 4    2017-08-31    Individual         Closed   2016-05-04
#
#               CLOSE-DT LAST-PAYMENT-DATE CREDIT-LIMIT/SANC AMT  \
# 0                  NaN               NaT                10,000
# 1                  NaN        2019-10-15                   NaN
# ...

# %%
test_b.shape
# Out:
# (64019, 20)

# %%
test_b.isnull().sum()
# Out:
# ID                               0
# SELF-INDICATOR                   0
# MATCH-TYPE                       0
# ACCT-TYPE                        0
# CONTRIBUTOR-TYPE                 0
# DATE-REPORTED                    0
# OWNERSHIP-IND                    0
# ACCOUNT-STATUS                   0
# DISBURSED-DT                    44
# CLOSE-DT                     31453
# LAST-PAYMENT-DATE            32550
# CREDIT-LIMIT/SANC AMT        62421
# DISBURSED-AMT/HIGH CREDIT       38
# INSTALLMENT-AMT              47693
# CURRENT-BAL                     32
# INSTALLMENT-FREQUENCY        48243
# OVERDUE-AMT                  13127
# WRITE-OFF-AMT                 2561
# ASSET_CLASS                  34902
# TENURE                       42882
# dtype: int64

# %%
test_b.head()
# Out:
#    ID  SELF-INDICATOR MATCH-TYPE      ACCT-TYPE CONTRIBUTOR-TYPE  \
# 0   4           False    PRIMARY    Credit Card              CCC
# 1   4           False    PRIMARY   Housing Loan              HFC
# 2   4           False    PRIMARY  Property Loan              HFC
# 3   4            True    PRIMARY   Tractor Loan              NBF
# 4   5           False    PRIMARY      Gold Loan              PRB
#
#   DATE-REPORTED OWNERSHIP-IND ACCOUNT-STATUS DISBURSED-DT  \
# 0    2019-11-17    Individual         Active   2019-09-26
# 1    2019-10-31         Joint         Active   2017-06-21
# 2    2019-10-31         Joint         Active   2017-06-27
# 3    2015-10-31    Individual         Closed   2011-12-29
# 4    2017-08-31    Individual         Closed   2016-05-04
#
#               CLOSE-DT LAST-PAYMENT-DATE CREDIT-LIMIT/SANC AMT  \
# 0                  NaN               NaT                10,000
# 1                  NaN        2019-10-15                   NaN
# ...

# %%
test_b.drop(['DATE-REPORTED', 'DISBURSED-DT', 'CLOSE-DT', 'LAST-PAYMENT-DATE', 'INSTALLMENT-FREQUENCY', 'ASSET_CLASS'], axis=1,inplace=True)
test_b.head()
# Out:
#    ID  SELF-INDICATOR MATCH-TYPE      ACCT-TYPE CONTRIBUTOR-TYPE  \
# 0   4           False    PRIMARY    Credit Card              CCC
# 1   4           False    PRIMARY   Housing Loan              HFC
# 2   4           False    PRIMARY  Property Loan              HFC
# 3   4            True    PRIMARY   Tractor Loan              NBF
# 4   5           False    PRIMARY      Gold Loan              PRB
#
#   OWNERSHIP-IND ACCOUNT-STATUS CREDIT-LIMIT/SANC AMT  \
# 0    Individual         Active                10,000
# 1         Joint         Active                   NaN
# 2         Joint         Active                   NaN
# 3    Individual         Closed                   NaN
# 4    Individual         Closed                   NaN
#
#   DISBURSED-AMT/HIGH CREDIT INSTALLMENT-AMT CURRENT-BAL OVERDUE-AMT  \
# 0                       588             NaN         589           0
# 1                 25,00,000  30,797/Monthly   21,07,227           0
# ...

# %%
test_b.shape
# Out:
# (64019, 14)

# %%
test_b.isnull().sum()
# Out:
# ID                               0
# SELF-INDICATOR                   0
# MATCH-TYPE                       0
# ACCT-TYPE                        0
# CONTRIBUTOR-TYPE                 0
# OWNERSHIP-IND                    0
# ACCOUNT-STATUS                   0
# CREDIT-LIMIT/SANC AMT        62421
# DISBURSED-AMT/HIGH CREDIT       38
# INSTALLMENT-AMT              47693
# CURRENT-BAL                     32
# OVERDUE-AMT                  13127
# WRITE-OFF-AMT                 2561
# TENURE                       42882
# dtype: int64

# %%
test_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64019 entries, 0 to 64018
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         64019 non-null  int64
#  1   SELF-INDICATOR             64019 non-null  bool
#  2   MATCH-TYPE                 64019 non-null  object
#  3   ACCT-TYPE                  64019 non-null  object
#  4   CONTRIBUTOR-TYPE           64019 non-null  object
#  5   OWNERSHIP-IND              64019 non-null  object
#  6   ACCOUNT-STATUS             64019 non-null  object
#  7   CREDIT-LIMIT/SANC AMT      1598 non-null   object
#  8   DISBURSED-AMT/HIGH CREDIT  63981 non-null  object
#  9   INSTALLMENT-AMT            16326 non-null  object
#  10  CURRENT-BAL                63987 non-null  object
#  11  OVERDUE-AMT                50892 non-null  object
#  12  WRITE-OFF-AMT              61458 non-null  float64
# ...

# %%
test_b['INSTALLMENT-AMT']=test_b['INSTALLMENT-AMT'].str.replace(',', '')
test_b['CREDIT-LIMIT/SANC AMT']=test_b['CREDIT-LIMIT/SANC AMT'].str.replace(',', '')
test_b['DISBURSED-AMT/HIGH CREDIT']=test_b['DISBURSED-AMT/HIGH CREDIT'].str.replace(',', '')
test_b['CURRENT-BAL']=test_b['CURRENT-BAL'].str.replace(',', '')
test_b['OVERDUE-AMT']=test_b['OVERDUE-AMT'].str.replace(',', '')
test_b.head()
# Out:
#    ID  SELF-INDICATOR MATCH-TYPE      ACCT-TYPE CONTRIBUTOR-TYPE  \
# 0   4           False    PRIMARY    Credit Card              CCC
# 1   4           False    PRIMARY   Housing Loan              HFC
# 2   4           False    PRIMARY  Property Loan              HFC
# 3   4            True    PRIMARY   Tractor Loan              NBF
# 4   5           False    PRIMARY      Gold Loan              PRB
#
#   OWNERSHIP-IND ACCOUNT-STATUS CREDIT-LIMIT/SANC AMT  \
# 0    Individual         Active                 10000
# 1         Joint         Active                   NaN
# 2         Joint         Active                   NaN
# 3    Individual         Closed                   NaN
# 4    Individual         Closed                   NaN
#
#   DISBURSED-AMT/HIGH CREDIT INSTALLMENT-AMT CURRENT-BAL OVERDUE-AMT  \
# 0                       588             NaN         589           0
# 1                   2500000   30797/Monthly     2107227           0
# ...

# %%
test_b['INSTALLMENT-AMT'].value_counts()
# Out:
# 0/Monthly          4913
# 0                   314
# 100000/Monthly      120
# 50000/Monthly        55
# 10000/Monthly        52
#                    ...
# 108424/BiWeekly       1
# 1147/Monthly          1
# 1722/Monthly          1
# 107706/Monthly        1
# 2708/Monthly          1
# Name: INSTALLMENT-AMT, Length: 7810, dtype: int64

# %%
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace(r'Single Payment Loan \(bullet / balloon\)', 'Monthly')
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace('/Monthly', '')
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace('/Other', '')
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace('/Quarterly', '')
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace('/BiWeekly', '')
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace('/Weekly', '')
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace('/Annually', '')
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace('/BiMonthly', '')
test_b['INSTALLMENT-AMT'] = test_b['INSTALLMENT-AMT'].str.replace('/Semi annually', '')

# %%
test_b.head()
# Out:
#    ID  SELF-INDICATOR MATCH-TYPE      ACCT-TYPE CONTRIBUTOR-TYPE  \
# 0   4           False    PRIMARY    Credit Card              CCC
# 1   4           False    PRIMARY   Housing Loan              HFC
# 2   4           False    PRIMARY  Property Loan              HFC
# 3   4            True    PRIMARY   Tractor Loan              NBF
# 4   5           False    PRIMARY      Gold Loan              PRB
#
#   OWNERSHIP-IND ACCOUNT-STATUS CREDIT-LIMIT/SANC AMT  \
# 0    Individual         Active                 10000
# 1         Joint         Active                   NaN
# 2         Joint         Active                   NaN
# 3    Individual         Closed                   NaN
# 4    Individual         Closed                   NaN
#
#   DISBURSED-AMT/HIGH CREDIT INSTALLMENT-AMT CURRENT-BAL OVERDUE-AMT  \
# 0                       588             NaN         589           0
# 1                   2500000           30797     2107227           0
# ...

# %%
test_b['CREDIT-LIMIT/SANC AMT'] = pd.to_numeric(test_b['CREDIT-LIMIT/SANC AMT'])
test_b['DISBURSED-AMT/HIGH CREDIT'] = pd.to_numeric(test_b['DISBURSED-AMT/HIGH CREDIT'])
test_b['INSTALLMENT-AMT'] = pd.to_numeric(test_b['INSTALLMENT-AMT'])
test_b['CURRENT-BAL'] = pd.to_numeric(test_b['CURRENT-BAL'])
test_b['OVERDUE-AMT'] = pd.to_numeric(test_b['OVERDUE-AMT'])
test_b['SELF-INDICATOR'] = test_b['SELF-INDICATOR'].astype(object)

# %%
test_b.head()
# Out:
#    ID SELF-INDICATOR MATCH-TYPE      ACCT-TYPE CONTRIBUTOR-TYPE OWNERSHIP-IND  \
# 0   4          False    PRIMARY    Credit Card              CCC    Individual
# 1   4          False    PRIMARY   Housing Loan              HFC         Joint
# 2   4          False    PRIMARY  Property Loan              HFC         Joint
# 3   4           True    PRIMARY   Tractor Loan              NBF    Individual
# 4   5          False    PRIMARY      Gold Loan              PRB    Individual
#
#   ACCOUNT-STATUS  CREDIT-LIMIT/SANC AMT  DISBURSED-AMT/HIGH CREDIT  \
# 0         Active                10000.0                      588.0
# 1         Active                    NaN                  2500000.0
# 2         Active                    NaN                    99000.0
# 3         Closed                    NaN                   365000.0
# 4         Closed                    NaN                    25801.0
#
#    INSTALLMENT-AMT  CURRENT-BAL  OVERDUE-AMT  WRITE-OFF-AMT  TENURE
# ...

# %%
test_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64019 entries, 0 to 64018
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         64019 non-null  int64
#  1   SELF-INDICATOR             64019 non-null  object
#  2   MATCH-TYPE                 64019 non-null  object
#  3   ACCT-TYPE                  64019 non-null  object
#  4   CONTRIBUTOR-TYPE           64019 non-null  object
#  5   OWNERSHIP-IND              64019 non-null  object
#  6   ACCOUNT-STATUS             64019 non-null  object
#  7   CREDIT-LIMIT/SANC AMT      1598 non-null   float64
#  8   DISBURSED-AMT/HIGH CREDIT  63981 non-null  float64
#  9   INSTALLMENT-AMT            16326 non-null  float64
#  10  CURRENT-BAL                63987 non-null  float64
#  11  OVERDUE-AMT                50892 non-null  float64
#  12  WRITE-OFF-AMT              61458 non-null  float64
# ...

# %%
test_b.fillna(0, inplace=True)
test_b.head()
# Out:
#    ID  SELF-INDICATOR MATCH-TYPE      ACCT-TYPE CONTRIBUTOR-TYPE  \
# 0   4           False    PRIMARY    Credit Card              CCC
# 1   4           False    PRIMARY   Housing Loan              HFC
# 2   4           False    PRIMARY  Property Loan              HFC
# 3   4            True    PRIMARY   Tractor Loan              NBF
# 4   5           False    PRIMARY      Gold Loan              PRB
#
#   OWNERSHIP-IND ACCOUNT-STATUS  CREDIT-LIMIT/SANC AMT  \
# 0    Individual         Active                10000.0
# 1         Joint         Active                    0.0
# 2         Joint         Active                    0.0
# 3    Individual         Closed                    0.0
# 4    Individual         Closed                    0.0
#
#    DISBURSED-AMT/HIGH CREDIT  INSTALLMENT-AMT  CURRENT-BAL  OVERDUE-AMT  \
# 0                      588.0              0.0        589.0          0.0
# 1                  2500000.0          30797.0    2107227.0          0.0
# ...

# %%
test_b.isnull().sum()
# Out:
# ID                           0
# SELF-INDICATOR               0
# MATCH-TYPE                   0
# ACCT-TYPE                    0
# CONTRIBUTOR-TYPE             0
# OWNERSHIP-IND                0
# ACCOUNT-STATUS               0
# CREDIT-LIMIT/SANC AMT        0
# DISBURSED-AMT/HIGH CREDIT    0
# INSTALLMENT-AMT              0
# CURRENT-BAL                  0
# OVERDUE-AMT                  0
# WRITE-OFF-AMT                0
# TENURE                       0
# dtype: int64

# %%
agg_func = {'CREDIT-LIMIT/SANC AMT' : ['mean'], 'DISBURSED-AMT/HIGH CREDIT' : ['mean'], 'INSTALLMENT-AMT': ['mean'], 'CURRENT-BAL': ['mean'], 'OVERDUE-AMT': ['mean'], 'WRITE-OFF-AMT': ['mean'], 'TENURE': ['mean']}
agg_name = test_b.groupby(['ID']).agg(agg_func)
agg_name.columns = [ 'AGG_' + ('_'.join(col).strip()) for col in agg_name.columns.values]
agg_name.reset_index(inplace=True)

# %%
agg_name
# Out:
#            ID  AGG_CREDIT-LIMIT/SANC AMT_mean  \
# 0           4                     2500.000000
# 1           5                        0.000000
# 2           6                        0.000000
# 3          25                        0.000000
# 4         119                        0.000000
# ...       ...                             ...
# 14740  143396                      128.205128
# 14741  143397                        0.000000
# 14742  143398                        0.000000
# 14743  143399                        0.000000
# 14744  143400                        0.000000
#
#        AGG_DISBURSED-AMT/HIGH CREDIT_mean  AGG_INSTALLMENT-AMT_mean  \
# 0                            7.411470e+05               8005.000000
# 1                            2.424766e+05               1282.500000
# 2                            2.697801e+05                  0.000000
# 3                            4.000000e+05                  0.000000
# ...

# %%
#test_b.groupby(['ID'])['SELF-INDICATOR'].agg(pd.Series.mode).to_frame()
#test_b.groupby(['ID'])['MATCH-TYPE'].agg(pd.Series.mode).to_frame()
#test_b.groupby(['ID'])['ACCT-TYPE'].agg(pd.Series.mode).to_frame()
#test_b.groupby(['ID'])['CONTRIBUTOR-TYPE'].agg(pd.Series.mode).to_frame()
#test_b.groupby(['ID'])['OWNERSHIP-IND'].agg(pd.Series.mode).to_frame()
#test_b.groupby(['ID'])['ACCOUNT-STATUS'].agg(pd.Series.mode).to_frame()

# %%
a=test_b.groupby(['ID'])['ACCOUNT-STATUS'].agg(pd.Series.mode).to_frame()
a.head()
# Out:
#        ACCOUNT-STATUS
# ID
# 4              Active
# 5              Closed
# 6              Closed
# 25   [Active, Closed]
# 119  [Active, Closed]

# %%
b=test_b.groupby(['ID'])['SELF-INDICATOR'].agg(pd.Series.mode).to_frame()
b.head()
# Out:
#     SELF-INDICATOR
# ID
# 4            False
# 5            False
# 6            False
# 25   [False, True]
# 119  [False, True]

# %%
c=test_b.groupby(['ID'])['MATCH-TYPE'].agg(pd.Series.mode).to_frame()
c.head()
# Out:
#     MATCH-TYPE
# ID
# 4      PRIMARY
# 5      PRIMARY
# 6      PRIMARY
# 25     PRIMARY
# 119    PRIMARY

# %%
e=test_b.groupby(['ID'])['CONTRIBUTOR-TYPE'].agg(pd.Series.mode).to_frame()
e.head()
# Out:
#     CONTRIBUTOR-TYPE
# ID
# 4                HFC
# 5         [NBF, PRB]
# 6                NBF
# 25        [NAB, NBF]
# 119              NBF

# %%
a = a.merge(b, on=['ID'])
a.head()
# Out:
#        ACCOUNT-STATUS SELF-INDICATOR
# ID
# 4              Active          False
# 5              Closed          False
# 6              Closed          False
# 25   [Active, Closed]  [False, True]
# 119  [Active, Closed]  [False, True]

# %%
a = a.merge(c, on=['ID'])
a.head()
# Out:
#        ACCOUNT-STATUS SELF-INDICATOR MATCH-TYPE
# ID
# 4              Active          False    PRIMARY
# 5              Closed          False    PRIMARY
# 6              Closed          False    PRIMARY
# 25   [Active, Closed]  [False, True]    PRIMARY
# 119  [Active, Closed]  [False, True]    PRIMARY

# %%
a = a.merge(e, on=['ID'])
a.head()
# Out:
#        ACCOUNT-STATUS SELF-INDICATOR MATCH-TYPE CONTRIBUTOR-TYPE
# ID
# 4              Active          False    PRIMARY              HFC
# 5              Closed          False    PRIMARY       [NBF, PRB]
# 6              Closed          False    PRIMARY              NBF
# 25   [Active, Closed]  [False, True]    PRIMARY       [NAB, NBF]
# 119  [Active, Closed]  [False, True]    PRIMARY              NBF

# %%
df =a
df.head()
# Out:
#        ACCOUNT-STATUS SELF-INDICATOR MATCH-TYPE CONTRIBUTOR-TYPE
# ID
# 4              Active          False    PRIMARY              HFC
# 5              Closed          False    PRIMARY       [NBF, PRB]
# 6              Closed          False    PRIMARY              NBF
# 25   [Active, Closed]  [False, True]    PRIMARY       [NAB, NBF]
# 119  [Active, Closed]  [False, True]    PRIMARY              NBF

# %%
df = df.merge(agg_name, on=['ID'])
df.head()
# Out:
#     ID    ACCOUNT-STATUS SELF-INDICATOR MATCH-TYPE CONTRIBUTOR-TYPE  \
# 0    4            Active          False    PRIMARY              HFC
# 1    5            Closed          False    PRIMARY       [NBF, PRB]
# 2    6            Closed          False    PRIMARY              NBF
# 3   25  [Active, Closed]  [False, True]    PRIMARY       [NAB, NBF]
# 4  119  [Active, Closed]  [False, True]    PRIMARY              NBF
#
#    AGG_CREDIT-LIMIT/SANC AMT_mean  AGG_DISBURSED-AMT/HIGH CREDIT_mean  \
# 0                          2500.0                       741147.000000
# 1                             0.0                       242476.625000
# 2                             0.0                       269780.083333
# 3                             0.0                       400000.000000
# 4                             0.0                       465000.000000
#
#    AGG_INSTALLMENT-AMT_mean  AGG_CURRENT-BAL_mean  AGG_OVERDUE-AMT_mean  \
# ...

# %%
df.shape
# Out:
# (14745, 12)

# %%
test1 = test.merge(agg_name, on=['ID'])
test1.head()
# Out:
#     ID    Frequency InstlmentMode LoanStatus PaymentMode  BranchID     Area  \
# 0    4      Monthly       Advance     Closed       PDC_E         2     GUNA
# 1    5      Monthly       Advance     Closed         PDC         2     GUNA
# 2    6      Quatrly        Arrear     Closed         PDC         2     GUNA
# 3   25  Half Yearly        Arrear     Closed      Billed       154      NaN
# 4  119      Quatrly        Arrear     Closed         PDC       194  CUTTACK
#
#    Tenure  AssetCost  AmountFinance  DisbursalAmount      EMI DisbursalDate  \
# 0      46     480000       365000.0         365000.0   1000.0    2011-12-29
# 1      45     480000       285000.0         285000.0   9300.0    2012-04-28
# 2      48     580000       400000.0         400000.0  35800.0    2013-10-22
# 3      36     725000       500000.0         500000.0  52000.0    2013-05-21
# 4      48     617000       400000.0         400000.0  35400.0    2012-11-30
#
# ...

# %%
test_new.shape
# Out:
# (14745, 32)

# %%
update_test = test.merge(df, on=['ID'])
update_test.head()
# Out:
#     ID    Frequency InstlmentMode LoanStatus PaymentMode  BranchID     Area  \
# 0    4      Monthly       Advance     Closed       PDC_E         2     GUNA
# 1    5      Monthly       Advance     Closed         PDC         2     GUNA
# 2    6      Quatrly        Arrear     Closed         PDC         2     GUNA
# 3   25  Half Yearly        Arrear     Closed      Billed       154      NaN
# 4  119      Quatrly        Arrear     Closed         PDC       194  CUTTACK
#
#    Tenure  AssetCost  AmountFinance  DisbursalAmount      EMI DisbursalDate  \
# 0      46     480000       365000.0         365000.0   1000.0    2011-12-29
# 1      45     480000       285000.0         285000.0   9300.0    2012-04-28
# 2      48     580000       400000.0         400000.0  35800.0    2013-10-22
# 3      36     725000       500000.0         500000.0  52000.0    2013-05-21
# 4      48     617000       400000.0         400000.0  35400.0    2012-11-30
#
# ...

# %%
update_test.shape
# Out:
# (14745, 36)

# %%
update_test.to_csv('test.csv')

# %%
test_new.to_csv('update_test.csv')
